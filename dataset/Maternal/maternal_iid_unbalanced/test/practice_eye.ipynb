# %%
import numpy as np

data = np.load('1.npz', allow_pickle=True)
lst = data.files

for item in lst:
    print(item)
    print(data[item])
# Out:
# data
# {'x': tensor([[[[ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#           [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#           [ 2.2318,  2.2318,  2.2318,  ...,  2.2489,  2.2489,  2.2318],
#           ...,
#           [-1.7240, -1.6898, -1.5870,  ..., -1.7754, -1.7240, -1.8782],
#           [-1.6384, -1.7583, -1.7240,  ..., -1.6555, -1.6727, -1.8439],
#           [-1.6898, -1.6555, -1.6727,  ..., -1.7583, -1.7069, -1.7412]],
#
#          [[ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#           [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#           [ 2.4111,  2.4111,  2.4111,  ...,  2.4286,  2.4286,  2.4111],
#           ...,
#           [-1.6331, -1.5980, -1.4930,  ..., -1.6856, -1.6331, -1.7906],
#           [-1.5455, -1.6681, -1.6331,  ..., -1.5630, -1.5805, -1.7556],
#           [-1.5980, -1.5630, -1.5805,  ..., -1.6681, -1.6155, -1.6506]],
#
# ...

# %%
l=data["data"]
extract_dict=l[()]
x=extract_dict["x"]
y=extract_dict['y']

# %%
x.shape
# Out:
# torch.Size([121, 3, 150, 150])

# %%
y
# Out:
# tensor([1, 1, 3, 3, 2, 2, 1, 2, 0, 0, 0, 2, 1, 0, 0, 1, 0, 1, 1, 0, 1, 3, 0, 0,
#         3, 1, 2, 3, 0, 3, 3, 1, 0, 3, 0, 3, 2, 2, 1, 1, 2, 2, 1, 2, 1, 1, 2, 0,
#         2, 2, 0, 1, 2, 3, 3, 3, 2, 2, 3, 1, 3, 2, 0, 0, 3, 3, 3, 3, 2, 2, 1, 2,
#         2, 2, 0, 3, 3, 1, 2, 0, 0, 1, 1, 3, 1, 0, 0, 1, 0, 3, 0, 3, 2, 2, 3, 0,
#         3, 2, 0, 0, 2, 0, 3, 1, 1, 2, 2, 1, 2, 3, 1, 2, 2, 3, 0, 0, 0, 3, 2, 3,
#         2])
